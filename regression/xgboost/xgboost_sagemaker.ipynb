# %%
import pandas as pd
import sagemaker, math, boto3, numpy as np
from pathlib import Path
from sklearn.datasets import load_boston
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

dataset = load_boston()

X = pd.DataFrame(dataset.data, columns=dataset.feature_names)
y = pd.DataFrame(dataset.target, columns=['PRICE'])
df = pd.concat(objs=[y,X], axis=1)

# %%
df.head(10)
# Out:
#    PRICE     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0   24.0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1   21.6  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2   34.7  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3   33.4  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4   36.2  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5   28.7  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6   22.9  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7   27.1  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8   16.5  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9   18.9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33
# 5     18.7  394.12   5.21
# 6     15.2  395.60  12.43
# 7     15.2  396.90  19.15
# 8     15.2  386.63  29.93
# 9     15.2  386.71  17.10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PRICE    506 non-null    float64
#  1   CRIM     506 non-null    float64
#  2   ZN       506 non-null    float64
#  3   INDUS    506 non-null    float64
#  4   CHAS     506 non-null    float64
#  5   NOX      506 non-null    float64
#  6   RM       506 non-null    float64
#  7   AGE      506 non-null    float64
#  8   DIS      506 non-null    float64
#  9   RAD      506 non-null    float64
#  10  TAX      506 non-null    float64
#  11  PTRATIO  506 non-null    float64
#  12  B        506 non-null    float64
#  13  LSTAT    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#             PRICE        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.532806    3.613524   11.363636   11.136779    0.069170    0.554695
# std      9.197104    8.601545   23.322453    6.860353    0.253994    0.115878
# min      5.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%     17.025000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%     21.200000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%     25.000000    3.677083   12.500000   18.100000    0.000000    0.624000
# max     50.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# std      0.702617   28.148861    2.105710    8.707259  168.537116    2.164946
# min      3.561000    2.900000    1.129600    1.000000  187.000000   12.600000
# 25%      5.885500   45.025000    2.100175    4.000000  279.000000   17.400000
# 50%      6.208500   77.500000    3.207450    5.000000  330.000000   19.050000
# 75%      6.623500   94.075000    5.188425   24.000000  666.000000   20.200000
# max      8.780000  100.000000   12.126500   24.000000  711.000000   22.000000
#
#                 B       LSTAT
# count  506.000000  506.000000
# mean   356.674032   12.653063
# std     91.294864    7.141062
# min      0.320000    1.730000
# 25%    375.377500    6.950000
# 50%    391.440000   11.360000
# 75%    396.225000   16.955000
# max    396.900000   37.970000

# %%
def get_s3_path(path):
    return f's3://{bucket_name}/xgboost/boston_dataset/{path}'

def get_s3_key(path):
    return f'xgboost/boston_dataset/{path}'

def get_local_path(path):
    dir_path = './datasets/xgboost/boston_dataset'

    Path(dir_path).mkdir(parents=True, exist_ok=True)

    return f'{dir_path}/{path}'

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.8, shuffle=True, random_state=0)

train_dataset = pd.concat(objs=[y_train, X_train], axis=1)
test_dataset = pd.concat(objs=[y_test, X_test], axis=1)

s3_client = boto3.client('s3')
bucket_name = 'ml-bucket-sagemaker'

train_dataset_path = get_local_path('train.csv')
test_dataset_path = get_local_path('test.csv')
train_dataset.to_csv(train_dataset_path, header=False, index=False)
test_dataset.to_csv(test_dataset_path, header=False, index=False)

s3_client.upload_file(train_dataset_path, bucket_name, get_s3_key('train.csv'))
s3_client.upload_file(test_dataset_path, bucket_name, get_s3_key('test.csv'))

# %%
sagemaker_session = sagemaker.Session()
region = sagemaker_session.boto_region_name
role = 'AmazonSageMaker-ExecutionRole-20211003T193315' # sagemaker.get_execution_role()

container = sagemaker.image_uris.retrieve('xgboost', region, '1.2-2')

model = sagemaker.estimator.Estimator(
    image_uri=container,
    role=role,
    instance_count=1,
    instance_type='ml.m5.2xlarge',
    volume_size=5,
    output_path=get_s3_path('model'),
    sagemaker_session=sagemaker_session,
)

model.set_hyperparameters(
    max_depth=5,
    learning_rate=0.1,
    objective='reg:squarederror',
    colsample_bytree=0.3,
    alpha=10,
    num_round=30,
    seed=0,
    eval_metric='rmse'
)

train_input = sagemaker.inputs.TrainingInput(get_s3_path('train.csv'), content_type='csv')
test_input = sagemaker.inputs.TrainingInput(get_s3_path('test.csv'), content_type='csv')

model.fit({
    'train': train_input,
    'validation': test_input,
})
# Out:
# 2021-10-09 16:20:47 Starting - Starting the training job...
# 2021-10-09 16:21:10 Starting - Launching requested ML instancesProfilerReport-1633796446: InProgress
# ......
# 2021-10-09 16:22:11 Starting - Preparing the instances for training...
# 2021-10-09 16:23:03 Downloading - Downloading input data...
# 2021-10-09 16:23:31 Training - Downloading the training image...
# 2021-10-09 16:24:06 Uploading - Uploading generated training model
# 2021-10-09 16:24:06 Completed - Training job completed
# [2021-10-09 16:23:53.189 ip-10-0-192-227.eu-west-1.compute.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-10-09:16:23:53:INFO] Imported framework sagemaker_xgboost_container.training
# [2021-10-09:16:23:53:INFO] Failed to parse hyperparameter eval_metric value rmse to Json.
# Returning the value itself
# [2021-10-09:16:23:53:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2021-10-09:16:23:53:INFO] No GPUs detected (normal if no gpus installed)
# [2021-10-09:16:23:53:INFO] Running XGBoost Sagemaker in algorithm mode
# [2021-10-09:16:23:53:INFO] Determined delimiter of CSV input is ','
# [2021-10-09:16:23:53:INFO] Determined delimiter of CSV input is ','
# [2021-10-09:16:23:53:INFO] Determined delimiter of CSV input is ','
# [2021-10-09:16:23:53:INFO] Determined delimiter of CSV input is ','
# [2021-10-09:16:23:53:INFO] Single node training.
# [2021-10-09:16:23:53:INFO] Train matrix has 101 rows and 13 columns
# [2021-10-09:16:23:53:INFO] Validation matrix has 405 rows
# [0]#011train-rmse:22.24654#011validation-rmse:21.55601
# [1]#011train-rmse:20.37804#011validation-rmse:19.70818
# [2]#011train-rmse:18.65914#011validation-rmse:18.03516
# [3]#011train-rmse:17.13651#011validation-rmse:16.56090
# [4]#011train-rmse:15.76825#011validation-rmse:15.29270
# [5]#011train-rmse:14.40211#011validation-rmse:14.04123
# [6]#011train-rmse:13.26045#011validation-rmse:12.98033
# [7]#011train-rmse:12.12056#011validation-rmse:11.93776
# [8]#011train-rmse:11.22733#011validation-rmse:11.13890
# [9]#011train-rmse:10.33324#011validation-rmse:10.32614
# [10]#011train-rmse:9.61685#011validation-rmse:9.72985
# [11]#011train-rmse:8.89968#011validation-rmse:9.17437
# [12]#011train-rmse:8.30582#011validation-rmse:8.68971
# [13]#011train-rmse:7.78324#011validation-rmse:8.27828
# [14]#011train-rmse:7.35176#011validation-rmse:7.93461
# [15]#011train-rmse:6.88036#011validation-rmse:7.55160
# [16]#011train-rmse:6.38141#011validation-rmse:7.26167
# [17]#011train-rmse:6.04459#011validation-rmse:7.08330
# [18]#011train-rmse:5.63262#011validation-rmse:6.84365
# [19]#011train-rmse:5.26131#011validation-rmse:6.65631
# [20]#011train-rmse:5.02970#011validation-rmse:6.51825
# [21]#011train-rmse:4.83951#011validation-rmse:6.38657
# [22]#011train-rmse:4.61239#011validation-rmse:6.27736
# [23]#011train-rmse:4.47453#011validation-rmse:6.19114
# [24]#011train-rmse:4.29511#011validation-rmse:6.11702
# [25]#011train-rmse:4.06171#011validation-rmse:5.98070
# [26]#011train-rmse:3.89255#011validation-rmse:5.86384
# [27]#011train-rmse:3.75410#011validation-rmse:5.81583
# [28]#011train-rmse:3.56434#011validation-rmse:5.76166
# [29]#011train-rmse:3.48105#011validation-rmse:5.72604
# Training seconds: 63
# Billable seconds: 63

# %%
# First-time deployment
predictor = model.deploy(
    endpoint_name='xgboost-boston-dataset',
    initial_instance_count=1,
    instance_type='ml.t2.medium',
    serializer=sagemaker.serializers.CSVSerializer()
)

# Re-use a pre-existing endpoint
# predictor = sagemaker.predictor.Predictor(
#     endpoint_name='xgboost-boston-dataset',
#     sagemaker=sagemaker_session,
#     serializer=sagemaker.serializers.CSVSerializer()
# )
# Out:
# -------!

# %%
def predict(data, rows=1000):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, predictor.predict(array).decode('utf-8')])
    return np.fromstring(predictions[1:], sep=',')

y_pre = predict(X_test.to_numpy())

mse = mean_squared_error(y_test, y_pre)
rmse = math.sqrt(mse)

print(f'RMSE: {rmse}')
# Out:
# RMSE: 5.151655979721133
